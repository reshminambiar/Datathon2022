# %% [markdown]
# <a href="https://colab.research.google.com/github/reshminambiar/Datathon2022/blob/main/Datathon__DataPreparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###This is the first task of the datathon project-Phonepe transaction geo visualization
# Hundreads of json files deep nested inside folders were given as the raw data. Our first challenge was to know which data is useful and should be taken, and bring them to a form where we can further work on it.

# %%
#Importing necessary libraries
import numpy as np
import pandas as pd
import os.path

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Here we have come up with code to retreive data from each of the json files and seggregated them to 6 dataframes

# %% [markdown]
# #DF for top->user

# %%
state = ['andaman-&-nicobar-islands','andhra-pradesh','arunachal-pradesh','assam','bihar','chandigarh','chhattisgarh',
         'dadra-&-nagar-haveli-&-daman-&-diu','delhi','goa','gujarat','haryana','himachal-pradesh','jammu-&-kashmir',
         'jharkhand','karnataka','kerala','ladakh','lakshadweep','madhya-pradesh','maharashtra','manipur',
         'meghalaya','mizoram','nagaland','odisha','puducherry','punjab','rajasthan','sikkim','tamil-nadu',
         'telangana','tripura','uttar-pradesh','uttarakhand','west-bengal']
years = ['2018','2019','2020','2021','2022']
quarters = ['1','2','3','4']
final=pd.DataFrame()
for s in state:
    for x in years:
        for y in quarters:
            path_="/content/drive/MyDrive/Datathon/data/top/user/country/india/state/{}/{}/{}.json".format(s,x,y)
            if(os.path.exists(path_)):
                with open(path_) as f:
                    data = json.load(f)
                    data=data['data']
                    name = str('df_'+s+x+y)
                    name = pd.DataFrame(data['districts'])
                    name = pd.concat([name,pd.DataFrame(data['pincodes'])])
                    name['state'] = s
                    name['year'] = x
                    name['quarter'] = y
                    final = pd.concat([final,name])

# %%
final.reset_index(drop=True)

# %%
final
# Out:
#                            name  registeredUsers                      state  \
# 0                 south andaman             5846  andaman-&-nicobar-islands
# 1      north and middle andaman              632  andaman-&-nicobar-islands
# 2                      nicobars              262  andaman-&-nicobar-islands
# 3                        744103             1608  andaman-&-nicobar-islands
# 4                        744101             1108  andaman-&-nicobar-islands
# ...                         ...              ...                        ...
# 11096                    700015            93175                west-bengal
# 11097                    742304            91059                west-bengal
# 11098                    721101            90324                west-bengal
# 11099                    700091            88432                west-bengal
# 11100                    700150            87552                west-bengal
#
#        year quarter
# 0      2018       1
# ...

# %%
final.to_csv('final_top_user.csv')

# %% [markdown]
# #DF for top->transaction

# %%
state = ['andaman-&-nicobar-islands','andhra-pradesh','arunachal-pradesh','assam','bihar','chandigarh','chhattisgarh',
         'dadra-&-nagar-haveli-&-daman-&-diu','delhi','goa','gujarat','haryana','himachal-pradesh','jammu-&-kashmir',
         'jharkhand','karnataka','kerala','ladakh','lakshadweep','madhya-pradesh','maharashtra','manipur',
         'meghalaya','mizoram','nagaland','odisha','puducherry','punjab','rajasthan','sikkim','tamil-nadu',
         'telangana','tripura','uttar-pradesh','uttarakhand','west-bengal']
years = ['2018','2019','2020','2021','2022']
quarters = ['1','2','3','4']
final_transaction_top=pd.DataFrame()
for s in state:
    for x in years:
        for y in quarters:
            path_="/content/drive/MyDrive/Datathon/data/top/transaction/country/india/state/{}/{}/{}.json".format(s,x,y)
            if(os.path.exists(path_)):
                with open(path_) as f:
                    data = json.load(f)
                    data=data['data']
                    name = str('df_'+s+x+y)
                    name = pd.DataFrame(data['districts'])
                    name = pd.concat([name,pd.DataFrame(data['pincodes'])])
                    name['state'] = s
                    name['year'] = x
                    name['quarter'] = y
                    final_transaction_top = pd.concat([final_transaction_top,name])
final_transaction_top.reset_index(inplace=True)
final_transaction_top
# Out:
#        index                entityName  \
# 0          0             south andaman
# 1          1                  nicobars
# 2          2  north and middle andaman
# 3          0                    744101
# 4          1                    744103
# ...      ...                       ...
# 11095      5                    742149
# 11096      6                    700135
# 11097      7                    700091
# 11098      8                    711101
# 11099      9                    721401
#
#                                                   metric  \
# 0      {'type': 'TOTAL', 'count': 5688, 'amount': 125...
# 1      {'type': 'TOTAL', 'count': 528, 'amount': 1139...
# 2      {'type': 'TOTAL', 'count': 442, 'amount': 9316...
# 3      {'type': 'TOTAL', 'count': 1622, 'amount': 276...
# 4      {'type': 'TOTAL', 'count': 1223, 'amount': 223...
# ...                                                  ...
# 11095  {'type': 'TOTAL', 'count': 1775561, 'amount': ...
# ...

# %%
final_transaction_top = pd.concat([final_transaction_top, final_transaction_top['metric'].apply(pd.Series)], axis = 1)

# %%
final_transaction_top.drop('metric',axis=1,inplace=True)

# %%
final_transaction_top.drop('type',axis=1,inplace=True)

# %%
final_transaction_top
# Out:
#                      entityName                      state  year quarter  \
# 0                 south andaman  andaman-&-nicobar-islands  2018       1
# 1                      nicobars  andaman-&-nicobar-islands  2018       1
# 2      north and middle andaman  andaman-&-nicobar-islands  2018       1
# 3                        744101  andaman-&-nicobar-islands  2018       1
# 4                        744103  andaman-&-nicobar-islands  2018       1
# ...                         ...                        ...   ...     ...
# 11095                    742149                west-bengal  2022       1
# 11096                    700135                west-bengal  2022       1
# 11097                    700091                west-bengal  2022       1
# 11098                    711101                west-bengal  2022       1
# 11099                    721401                west-bengal  2022       1
#
#          count        amount
# 0         5688  1.256025e+07
# 1          528  1.139849e+06
# ...

# %%
final_transaction_top.to_csv('final_transaction_top.csv')

# %% [markdown]
# #DF for map->user

# %%
state = ['andaman-&-nicobar-islands','andhra-pradesh','arunachal-pradesh','assam','bihar','chandigarh','chhattisgarh',
         'dadra-&-nagar-haveli-&-daman-&-diu','delhi','goa','gujarat','haryana','himachal-pradesh','jammu-&-kashmir',
         'jharkhand','karnataka','kerala','ladakh','lakshadweep','madhya-pradesh','maharashtra','manipur',
         'meghalaya','mizoram','nagaland','odisha','puducherry','punjab','rajasthan','sikkim','tamil-nadu',
         'telangana','tripura','uttar-pradesh','uttarakhand','west-bengal']
years = ['2018','2019','2020','2021','2022']
quarters = ['1','2','3','4']
final_map_user=pd.DataFrame()
for s in state:
    for x in years:
        for y in quarters:
            path_="/content/drive/MyDrive/Datathon/data/map/user/hover/country/india/state/{}/{}/{}.json".format(s,x,y)
            if(os.path.exists(path_)):
                with open(path_) as f:
                    data = json.load(f)
                    data=data['data']['hoverData']
                    name = str('df_'+s+x+y)
                    #name = pd.DataFrame(data)
                    name = pd.DataFrame.from_dict(data, orient = 'index')
                    #name = pd.concat([name,pd.DataFrame(data['pincodes'])])
                    name['state'] = s
                    name['year'] = x
                    name['quarter'] = y
                    final_map_user = pd.concat([final_map_user,name])

# %%
data
# Out:
# {'alipurduar district': {'appOpens': 8375579, 'registeredUsers': 223296},
#  'bankura district': {'appOpens': 16485113, 'registeredUsers': 790092},
#  'birbhum district': {'appOpens': 9448003, 'registeredUsers': 733911},
#  'dakshin dinajpur district': {'appOpens': 4987259, 'registeredUsers': 348440},
#  'darjiling district': {'appOpens': 7587920, 'registeredUsers': 485846},
#  'hooghly district': {'appOpens': 7217576, 'registeredUsers': 1356282},
#  'howrah district': {'appOpens': 4852911, 'registeredUsers': 1218931},
#  'jalpaiguri district': {'appOpens': 10959051, 'registeredUsers': 321098},
#  'jhargram district': {'appOpens': 6036561, 'registeredUsers': 152675},
#  'kalimpong district': {'appOpens': 4063572, 'registeredUsers': 46360},
#  'koch bihar district': {'appOpens': 11039904, 'registeredUsers': 459613},
#  'kolkata district': {'appOpens': 8737523, 'registeredUsers': 2340343},
#  'maldah district': {'appOpens': 11245507, 'registeredUsers': 812775},
# ...

# %%
final_map_user
# Out:
#                                    registeredUsers  appOpens  \
# north and middle andaman district              632         0
# south andaman district                        5846         0
# nicobars district                              262         0
# north and middle andaman district              911         0
# south andaman district                        8143         0
# ...                                            ...       ...
# nadia district                             1164783   8989674
# birbhum district                            733911   9448003
# purba medinipur district                   1155279   8760746
# maldah district                             812775  11245507
# darjiling district                          485846   7587920
#
#                                                        state  year quarter
# north and middle andaman district  andaman-&-nicobar-islands  2018       1
# south andaman district             andaman-&-nicobar-islands  2018       1
# ...

# %%
final_map_user = final_map_user.reset_index()

# %%
final_map_user
# Out:
#                                    index  registeredUsers  appOpens  \
# 0      north and middle andaman district              632         0
# 1                 south andaman district             5846         0
# 2                      nicobars district              262         0
# 3      north and middle andaman district              911         0
# 4                 south andaman district             8143         0
# ...                                  ...              ...       ...
# 12439                     nadia district          1164783   8989674
# 12440                   birbhum district           733911   9448003
# 12441           purba medinipur district          1155279   8760746
# 12442                    maldah district           812775  11245507
# 12443                 darjiling district           485846   7587920
#
#                            state  year quarter
# 0      andaman-&-nicobar-islands  2018       1
# 1      andaman-&-nicobar-islands  2018       1
# ...

# %%
final_map_user.to_csv('final_map_user_new.csv')

# %% [markdown]
# #DF for map->transaction

# %%
state = ['andaman-&-nicobar-islands','andhra-pradesh','arunachal-pradesh','assam','bihar','chandigarh','chhattisgarh',
         'dadra-&-nagar-haveli-&-daman-&-diu','delhi','goa','gujarat','haryana','himachal-pradesh','jammu-&-kashmir',
         'jharkhand','karnataka','kerala','ladakh','lakshadweep','madhya-pradesh','maharashtra','manipur',
         'meghalaya','mizoram','nagaland','odisha','puducherry','punjab','rajasthan','sikkim','tamil-nadu',
         'telangana','tripura','uttar-pradesh','uttarakhand','west-bengal']
years = ['2018','2019','2020','2021','2022']
quarters = ['1','2','3','4']
final_map_transaction=pd.DataFrame()
for s in state:
    for x in years:
        for y in quarters:
            path_="/content/drive/MyDrive/Datathon/data/map/transaction/hover/country/india/state/{}/{}/{}.json".format(s,x,y)
            if(os.path.exists(path_)):
                with open(path_) as f:
                    data = json.load(f)
                    data=data['data']['hoverDataList']
                    name = str('df_'+s+x+y)
                    name = pd.DataFrame(data)
                    name['state'] = s
                    name['year'] = x
                    name['quarter'] = y
                    final_map_transaction = pd.concat([final_map_transaction,name])
final_map_transaction.reset_index(inplace=True)
final_map_transaction
# Out:
#        index                               name  \
# 0          0  north and middle andaman district
# 1          1             south andaman district
# 2          2                  nicobars district
# 3          0  north and middle andaman district
# 4          1             south andaman district
# ...      ...                                ...
# 12435     18                     nadia district
# 12436     19                   birbhum district
# 12437     20           purba medinipur district
# 12438     21                    maldah district
# 12439     22                 darjiling district
#
#                                                   metric  \
# 0      [{'type': 'TOTAL', 'count': 442, 'amount': 931...
# 1      [{'type': 'TOTAL', 'count': 5688, 'amount': 12...
# 2      [{'type': 'TOTAL', 'count': 528, 'amount': 113...
# 3      [{'type': 'TOTAL', 'count': 825, 'amount': 131...
# 4      [{'type': 'TOTAL', 'count': 9395, 'amount': 23...
# ...

# %%
final_map_transaction['metric'] = final_map_transaction['metric'].apply(lambda x:x[0])

# %%
final_map_transaction = pd.concat([final_map_transaction, final_map_transaction['metric'].apply(pd.Series)], axis = 1)
final_map_transaction.drop(['metric','type'],axis=1,inplace=True)
final_map_transaction
# Out:
#        index                               name                      state  \
# 0          0  north and middle andaman district  andaman-&-nicobar-islands
# 1          1             south andaman district  andaman-&-nicobar-islands
# 2          2                  nicobars district  andaman-&-nicobar-islands
# 3          0  north and middle andaman district  andaman-&-nicobar-islands
# 4          1             south andaman district  andaman-&-nicobar-islands
# ...      ...                                ...                        ...
# 12435     18                     nadia district                west-bengal
# 12436     19                   birbhum district                west-bengal
# 12437     20           purba medinipur district                west-bengal
# 12438     21                    maldah district                west-bengal
# 12439     22                 darjiling district                west-bengal
#
#        year quarter     count        amount
# ...

# %%
final_map_transaction.drop('index', axis=1, inplace=True)
final_map_transaction
# Out:
#                                     name                      state  year  \
# 0      north and middle andaman district  andaman-&-nicobar-islands  2018
# 1                 south andaman district  andaman-&-nicobar-islands  2018
# 2                      nicobars district  andaman-&-nicobar-islands  2018
# 3      north and middle andaman district  andaman-&-nicobar-islands  2018
# 4                 south andaman district  andaman-&-nicobar-islands  2018
# ...                                  ...                        ...   ...
# 12435                     nadia district                west-bengal  2022
# 12436                   birbhum district                west-bengal  2022
# 12437           purba medinipur district                west-bengal  2022
# 12438                    maldah district                west-bengal  2022
# 12439                 darjiling district                west-bengal  2022
#
#       quarter     count        amount
# 0           1       442  9.316631e+05
# ...

# %%
final_map_transaction.to_csv('final_map_transaction.csv')

# %% [markdown]
# #DF for Aggregated->user

# %%
state = ['andaman-&-nicobar-islands','andhra-pradesh','arunachal-pradesh','assam','bihar','chandigarh','chhattisgarh',
         'dadra-&-nagar-haveli-&-daman-&-diu','delhi','goa','gujarat','haryana','himachal-pradesh','jammu-&-kashmir',
         'jharkhand','karnataka','kerala','ladakh','lakshadweep','madhya-pradesh','maharashtra','manipur',
         'meghalaya','mizoram','nagaland','odisha','puducherry','punjab','rajasthan','sikkim','tamil-nadu',
         'telangana','tripura','uttar-pradesh','uttarakhand','west-bengal']
years = ['2018','2019','2020','2021','2022']
quarters = ['1','2','3','4']
final_agg_user=pd.DataFrame()
for s in state:
    for x in years:
        for y in quarters:
            path_="/content/drive/MyDrive/Datathon/data/aggregated/user/country/india/state/{}/{}/{}.json".format(s,x,y)
            if(os.path.exists(path_)):
                with open(path_) as f:
                    data = json.load(f)
                    data=data['data']['usersByDevice']
                    name = str('df_'+s+x+y)
                    name = pd.DataFrame(data)
                    name['state'] = s
                    name['year'] = x
                    name['quarter'] = y
                    final_agg_user = pd.concat([final_agg_user,name])

# %%
final_agg_user
# Out:
#       brand    count  percentage                      state  year quarter
# 0    Xiaomi     1665    0.247033  andaman-&-nicobar-islands  2018       1
# 1   Samsung     1445    0.214392  andaman-&-nicobar-islands  2018       1
# 2      Vivo      982    0.145697  andaman-&-nicobar-islands  2018       1
# 3      Oppo      501    0.074332  andaman-&-nicobar-islands  2018       1
# 4   OnePlus      332    0.049258  andaman-&-nicobar-islands  2018       1
# ..      ...      ...         ...                        ...   ...     ...
# 6    Lenovo   330017    0.015056                west-bengal  2022       1
# 7   Infinix   284678    0.012987                west-bengal  2022       1
# 8      Asus   280347    0.012790                west-bengal  2022       1
# 9     Apple   277752    0.012671                west-bengal  2022       1
# 10   Others  2196334    0.100199                west-bengal  2022       1
#
# [6732 rows x 6 columns]

# %%
final_agg_user.to_csv('final_agg_user.csv')

# %% [markdown]
# #DF for Aggregated->Transaction

# %%
state = ['andaman-&-nicobar-islands','andhra-pradesh','arunachal-pradesh','assam','bihar','chandigarh','chhattisgarh',
         'dadra-&-nagar-haveli-&-daman-&-diu','delhi','goa','gujarat','haryana','himachal-pradesh','jammu-&-kashmir',
         'jharkhand','karnataka','kerala','ladakh','lakshadweep','madhya-pradesh','maharashtra','manipur',
         'meghalaya','mizoram','nagaland','odisha','puducherry','punjab','rajasthan','sikkim','tamil-nadu',
         'telangana','tripura','uttar-pradesh','uttarakhand','west-bengal']
years = ['2018','2019','2020','2021','2022']
quarters = ['1','2','3','4']
final_agg_transaction=pd.DataFrame()
for s in state:
    for x in years:
        for y in quarters:
            path_="/content/drive/MyDrive/Datathon/data/aggregated/transaction/country/india/state/{}/{}/{}.json".format(s,x,y)
            if(os.path.exists(path_)):
                with open(path_) as f:
                    data = json.load(f)
                    data=data['data']['transactionData']
                    name = str('df_'+s+x+y)
                    name = pd.DataFrame(data)
                    name['state'] = s
                    name['year'] = x
                    name['quarter'] = y
                    final_agg_transaction = pd.concat([final_agg_transaction,name])
final_agg_transaction
# Out:
#                         name  \
# 0   Recharge & bill payments
# 1      Peer-to-peer payments
# 2          Merchant payments
# 3         Financial Services
# 4                     Others
# ..                       ...
# 0      Peer-to-peer payments
# 1          Merchant payments
# 2   Recharge & bill payments
# 3         Financial Services
# 4                     Others
#
#                                    paymentInstruments  \
# 0   [{'type': 'TOTAL', 'count': 4200, 'amount': 18...
# 1   [{'type': 'TOTAL', 'count': 1871, 'amount': 12...
# 2   [{'type': 'TOTAL', 'count': 298, 'amount': 452...
# 3   [{'type': 'TOTAL', 'count': 33, 'amount': 1060...
# 4   [{'type': 'TOTAL', 'count': 256, 'amount': 184...
# ..                                                ...
# 0   [{'type': 'TOTAL', 'count': 124787028, 'amount...
# 1   [{'type': 'TOTAL', 'count': 97315025, 'amount'...
# 2   [{'type': 'TOTAL', 'count': 37317865, 'amount'...
# 3   [{'type': 'TOTAL', 'count': 239530, 'amount': ...
# ...

# %%
final_agg_transaction['paymentInstruments'] = final_agg_transaction['paymentInstruments'].apply(lambda x:x[0])

# %%
final_agg_transaction = pd.concat([final_agg_transaction, final_agg_transaction['paymentInstruments'].apply(pd.Series)], axis = 1)
final_agg_transaction.drop(['paymentInstruments'],axis=1,inplace=True)

# %%
final_agg_transaction
# Out:
#                         name                      state  year quarter   type  \
# 0   Recharge & bill payments  andaman-&-nicobar-islands  2018       1  TOTAL
# 1      Peer-to-peer payments  andaman-&-nicobar-islands  2018       1  TOTAL
# 2          Merchant payments  andaman-&-nicobar-islands  2018       1  TOTAL
# 3         Financial Services  andaman-&-nicobar-islands  2018       1  TOTAL
# 4                     Others  andaman-&-nicobar-islands  2018       1  TOTAL
# ..                       ...                        ...   ...     ...    ...
# 0      Peer-to-peer payments                west-bengal  2022       1  TOTAL
# 1          Merchant payments                west-bengal  2022       1  TOTAL
# 2   Recharge & bill payments                west-bengal  2022       1  TOTAL
# 3         Financial Services                west-bengal  2022       1  TOTAL
# 4                     Others                west-bengal  2022       1  TOTAL
#
#         count        amount
# ...

# %%
final_agg_transaction.reset_index(drop=True, inplace=True)

# %%
final_agg_transaction.drop('type',axis=1, inplace=True)

# %%
final_agg_transaction
# Out:
#                           name                      state  year quarter  \
# 0     Recharge & bill payments  andaman-&-nicobar-islands  2018       1
# 1        Peer-to-peer payments  andaman-&-nicobar-islands  2018       1
# 2            Merchant payments  andaman-&-nicobar-islands  2018       1
# 3           Financial Services  andaman-&-nicobar-islands  2018       1
# 4                       Others  andaman-&-nicobar-islands  2018       1
# ...                        ...                        ...   ...     ...
# 3049     Peer-to-peer payments                west-bengal  2022       1
# 3050         Merchant payments                west-bengal  2022       1
# 3051  Recharge & bill payments                west-bengal  2022       1
# 3052        Financial Services                west-bengal  2022       1
# 3053                    Others                west-bengal  2022       1
#
#           count        amount
# 0          4200  1.845307e+06
# 1          1871  1.213866e+07
# ...

# %%
final_agg_transaction.to_csv('final_agg_transaction.csv')

# %% [markdown]
# #Trial code
# The below code is just a sample with a single file to know how structure of json and whether code will work.This is for reference and need not be executed.

# %%
df = pd.read_json('1.json')

# %%
df
# Out:
#            success     code  \
# districts     True  SUCCESS
# pincodes      True  SUCCESS
# states        True  SUCCESS
#
#                                                         data  \
# districts  [{'entityName': 'south andaman', 'metric': {'t...
# pincodes   [{'entityName': '744101', 'metric': {'type': '...
# states                                                  None
#
#            responseTimestamp
# districts      1630501486876
# pincodes       1630501486876
# states         1630501486876

# %%
df1 = pd.DataFrame(df.data)

# %%
df1
# Out:
#                                                         data
# districts  [{'entityName': 'south andaman', 'metric': {'t...
# pincodes   [{'entityName': '744101', 'metric': {'type': '...
# states                                                  None

# %%
import json
with open('1.json') as f:
    data = json.load(f)

# %%
data=data['data']

# %%
data
# Out:
# {'districts': [{'entityName': 'south andaman',
#    'metric': {'amount': 12560249.343665812, 'count': 5688, 'type': 'TOTAL'}},
#   {'entityName': 'nicobars',
#    'metric': {'amount': 1139848.801225994, 'count': 528, 'type': 'TOTAL'}},
#   {'entityName': 'north and middle andaman',
#    'metric': {'amount': 931663.0770939873, 'count': 442, 'type': 'TOTAL'}}],
#  'pincodes': [{'entityName': '744101',
#    'metric': {'amount': 2769297.9039997994, 'count': 1622, 'type': 'TOTAL'}},
#   {'entityName': '744103',
#    'metric': {'amount': 2238041.8716124697, 'count': 1223, 'type': 'TOTAL'}},
#   {'entityName': '744102',
#    'metric': {'amount': 3519059.937562449, 'count': 969, 'type': 'TOTAL'}},
#   {'entityName': '744105',
#    'metric': {'amount': 1298560.9515503529, 'count': 685, 'type': 'TOTAL'}},
#   {'entityName': '744104',
#    'metric': {'amount': 1039715.3111450541, 'count': 340, 'type': 'TOTAL'}},
#   {'entityName': '744107',
# ...

# %%
df = pd.DataFrame(data['districts'])

# %%
df
# Out:
#                  entityName                                             metric
# 0             south andaman  {'type': 'TOTAL', 'count': 5688, 'amount': 125...
# 1                  nicobars  {'type': 'TOTAL', 'count': 528, 'amount': 1139...
# 2  north and middle andaman  {'type': 'TOTAL', 'count': 442, 'amount': 9316...

# %%
for x in range(len(data['districts'])):
    
    df = pd.DataFrame([data['districts'][x])
# Out:
# {'entityName': 'south andaman', 'metric': {'type': 'TOTAL', 'count': 5688, 'amount': 12560249.343665812}}
# {'entityName': 'nicobars', 'metric': {'type': 'TOTAL', 'count': 528, 'amount': 1139848.801225994}}
# {'entityName': 'north and middle andaman', 'metric': {'type': 'TOTAL', 'count': 442, 'amount': 931663.0770939873}}

# %%
df = pd.json_normalize(data)

# %%
df

# %%
df1 = df['districts']

# %% [markdown]
# #State Data
# The below code is just a sample with a single file to know how structure of json and whether code will work.This is for reference and need not be executed.

# %%
df = pd.read_json('/content/drive/MyDrive/Datathon/data/aggregated/user/country/india/state/andaman-&-nicobar-islands/2018/1.json')

# %%
df = df.data

# %%
df.head()
# Out:
# aggregated                {'registeredUsers': 6740, 'appOpens': 0}
# usersByDevice    [{'brand': 'Xiaomi', 'count': 1665, 'percentag...
# Name: data, dtype: object

# %%
import json
with open('/content/drive/MyDrive/Datathon/data/aggregated/user/country/india/state/andaman-&-nicobar-islands/2018/2.json') as f:
    data = json.load(f)

# %%
#data=data['data']['hoverData']
data
# Out:
# {'code': 'SUCCESS',
#  'data': {'aggregated': {'appOpens': 0, 'registeredUsers': 9405},
#   'usersByDevice': [{'brand': 'Xiaomi',
#     'count': 2303,
#     'percentage': 0.24486975013290802},
#    {'brand': 'Samsung', 'count': 1923, 'percentage': 0.20446570972886763},
#    {'brand': 'Vivo', 'count': 1523, 'percentage': 0.1619351408825093},
#    {'brand': 'Oppo', 'count': 708, 'percentage': 0.07527910685805422},
#    {'brand': 'OnePlus', 'count': 466, 'percentage': 0.049548112706007445},
#    {'brand': 'Realme', 'count': 465, 'percentage': 0.049441786283891544},
#    {'brand': 'Motorola', 'count': 319, 'percentage': 0.03391812865497076},
#    {'brand': 'Apple', 'count': 308, 'percentage': 0.03274853801169591},
#    {'brand': 'Lenovo', 'count': 244, 'percentage': 0.025943646996278574},
#    {'brand': 'Huawei', 'count': 230, 'percentage': 0.024455077086656035},
#    {'brand': 'Others', 'count': 916, 'percentage': 0.09739500265816055}]},
#  'responseTimestamp': 1630501494939,
# ...

# %%
for x in range(len(data['districts'])):
    print(data['districts'][x])
# Out:
# {'name': 'south andaman', 'registeredUsers': 5846}
# {'name': 'north and middle andaman', 'registeredUsers': 632}
# {'name': 'nicobars', 'registeredUsers': 262}

# %%
df1 = pd.DataFrame(data['districts'])

# %%
df1
# Out:
#                        name  registeredUsers
# 0             south andaman             5846
# 1  north and middle andaman              632
# 2                  nicobars              262

# %%
df1 = pd.concat([df1,pd.DataFrame(data['pincodes'])])

# %%
df1['state'] = 'andaman-&-nicobar-islands'

# %%
df1['year']='2018'

# %%
df1
# Out:
#                        name  registeredUsers                      state  year
# 0             south andaman             5846  andaman-&-nicobar-islands  2018
# 1  north and middle andaman              632  andaman-&-nicobar-islands  2018
# 2                  nicobars              262  andaman-&-nicobar-islands  2018
# 0                    744103             1608  andaman-&-nicobar-islands  2018
# 1                    744101             1108  andaman-&-nicobar-islands  2018
# 2                    744105             1075  andaman-&-nicobar-islands  2018
# 3                    744102             1006  andaman-&-nicobar-islands  2018
# 4                    744104              272  andaman-&-nicobar-islands  2018
# 5                    744202              237  andaman-&-nicobar-islands  2018
# 6                    744112              215  andaman-&-nicobar-islands  2018
# 7                    744301              207  andaman-&-nicobar-islands  2018
# ...
